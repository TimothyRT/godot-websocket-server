# %%
from ahrs.filters import Mahony

# %%
import numpy as np

# %%
gyro_data = np.array([[-13, 5, 2]])
acc_data = np.array([[4, -6, 3]])

# %%
orientation = Mahony(gyr=gyro_data, acc=acc_data)

# %%
print(orientation.Q)
# Out:
# [[ 0.82009477 -0.50684644 -0.22594549 -0.13964199]]
