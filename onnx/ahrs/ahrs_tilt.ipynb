# %% [markdown]
# Tes penggunaan tilt estimation

# %%
import numpy as np
from ahrs.filters import Tilt

# %%
acc_data = np.array([4.098297, 8.663757, 2.1355896])
mag_data = np.array([-28.71550512, -25.92743566, 4.75683931])

# %%
tilt = Tilt()
tilt.estimate(acc=acc_data, mag=mag_data, representation="quaternion")   # Estimate attitude as quaternion
# Out:
# array([0.09867706, 0.33683592, 0.52706394, 0.77395607])

# %%
arr = np.array([4.098297, 8.663757, 2.13559])
print(np.linalg.norm(arr))
# Out:
# 9.81923970088102

# %%
from ahrs.filters import FKF
